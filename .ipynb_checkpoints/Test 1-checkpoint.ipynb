# %% [markdown]
# # Comparing control architectures designs with greedy selection

# %% [markdown]
# ###### Python package initializer

# %%
import numpy as np
# from IPython.display import display, Latex

from functionfile_model import system_package1, create_graph, simulate_system, solve_constraints_initializer, plot_trajectory, plot_trajectory_comparisons
print('Package initialization complete')

# %matplotlib widget
# Out:
# Package initialization complete

# %% [markdown]
# ### Introduction

# %% [markdown]
# We compare 4 stages of control architecture with full-state feedback gain design
# - Type 1: Design-time random actuator selection $B_S$ and design-time fixed feedback $K$ gain design
#
# Possibly suboptimal control architecture should result with the highest control costs even with optimal gains
#
# - Type 2: Design-time greedy actuator selection $B_S$ and design-time fixed feedback $K$ gain design
#
# Design-time architecture optimization should result with lower control costs than Type 1 but higher than Type 4 gains
#
# - Type 3: Design-time greedy actuator selection $B_S$ and run-time feedback gain $K_t$ design with current state $x_t$ information
#
# Design-time architecture is independent of $x_t$ and $K_t$ is independent of $x_t$ so expect identical results to Type 3
#
# - Type 4: Run-time greedy actuator selection $B_{S,t}$ and run-time feedback gain $K_t$ design with current state $x_t$ information
#
# Run-time architecture optimization using $x_t$ should result in better architecture than Type 2 and result with lowest control cost

# %% [markdown]
# ### System Definition
#
# System dynamics: $ x_{t+1} = A x_{t} + B_S u_{t} + w_{t} $
#
# Open-loop dynamics: $A$ randomly generated, well-connected, undirected, uniformly weighted, ER network $(p=0.4)$ with $n_x=50$ nodes, scaled such that $|\lambda_{max}(A)|=1.2$
#
# Actuator: $B_S$ or $B_{S,t}$ with cardinality constraint $|S|<=2$
#
# Initial states: Randomly sampled from $X_0 = 20 \times \mathbf{I}_{n_x}$
#
# Additive disturbances: Randomly sampled from $W = 5 \times \mathbf{I}_{n_x}$

# %%
nx = 50
p = 0.4
rho = 1.2

A = rho*create_graph(nx, 'ER', p)['A']
# A = rho*create_graph(nx, 'rand')['A']
S = 2
X0 = 20*np.random.rand(nx)
W = 5*np.identity(nx)

Sys = system_package1(A, S_in=S, X0_in=X0, W_in=W)

solve_constraints = solve_constraints_initializer(Sys)

# %% [markdown]
# ### Run Code

# %%
simulate_results = {}

for K_type in [1, 2, 3, 4]:
    simulate_results[K_type] = simulate_system(Sys, K_type, solve_constraints)
# Out:
# Type 1: Design-time random $B_S$, $K$
#       - Simulation complete
# Type 2: Design-time greedy $B_S$, $K$
#       - Simulation complete
# Type 3: Design-time greedy $B_S$, run-time $K_t$ with $x_t$
#       - Simulation complete
# Type 4: Run-time greedy $B_{S,t}$, $K_t$ with $x_t$
#       - Simulation complete

# %% [markdown]
# ### Results

# %%
plot_trajectory_comparisons(simulate_results)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Cumulative cost comparison:
# Type 1 : 225043.60
# Type 2 : 104820.95
# Type 3 : 104820.95
# Type 4 : 103180.44
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
